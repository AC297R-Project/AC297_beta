# %%
import Quandl
import pandas as pd
import numpy as np

# %%
#Global Variables
SECTORS = ['Basic Industries', 'Capital Goods', 'Consumer Durables', 'Consumer Non-Durables','Consumer Services', 
           'Energy', 'Finance', 'Health Care', 'Miscellaneous', 'Public Utilities', 'Technology', 'Transportation', 'n/a']
MARKETS = ['NYSE', 'NASDAQ', 'AMEX']

# %%
def getStockUniverse(directory = '../../data/', NYSE = True, NASDAQ = True, AMEX = True):
    """
    Reads in the stored stock data, including symbol, Name, Cap, Sector, Industry from NYSE, NASDAQ and AMEX
    
    Returns
    -------
    A pandas frame concatenating all the stock universe from NYSE, NASDAQ and AMEX
    """
    nyse = pd.read_csv(directory+'companylist_nyse.csv')
    nyse['Market'] = 'NYSE'
    nasdaq = pd.read_csv(directory+'companylist_nasdaq.csv')
    nasdaq['Market'] = 'NASDAQ'
    amex = pd.read_csv(directory+'companylist_amex.csv')
    amex['Market'] = 'AMEX'
    
    allstocks = pd.concat([nyse,nasdaq,amex])
    
    # The following parses the market cap into more readable fashion
    # eg. $1.15B = 1150, n/a = -1
    def parseMarketCap(allstocks):
        cap = allstocks['MarketCap'].values
        def computeCap(s):
            if s=='n/a':
                return -1
            elif s[-1:]=='B':
                return float(s[1:-1])*1000
            elif s[-1:]=='M':
                return float(s[1:-1])
        allstocks['MarketCap'] = map(computeCap, cap)
    
    allstocks = allstocks.drop('Unnamed: 8', axis = 1)
    parseMarketCap(allstocks)
    
    allstocks = allstocks.drop_duplicates('Name')    #Drop duplicates, eg. GOOG instead of GOOGL

    return allstocks.sort_values(by = 'MarketCap', ascending = False).reset_index().drop('index', axis=1)

# %%
def getSamplePortfolio(stock_universe, n = 10, capThreshold = 2000,
                       sector = None, descendingByCap = False, market = ['NYSE', 'NASDAQ']):
    """
    Get a sample portfolio from the stock universe, preferably a generated one from getStockUniverse.
    With specified parameters.
    
    Parameters
    ----------
    stock_universe : pandas frame with symbols, Cap and Sector
    n : number of samples
    capThreshold : sample should be larger than this threshold, initially set ot 2000
    sector : list of specific sectors to sample from, default to None with no preference
    DescendingByCap: Sample the largest caps, otherwise random sampling.
    market : specific market to sample from, NYSE, NASDAQ and AMEX, default is NYSE and NASDAQ.
    
    Returns
    ------
    A list of symbols
    """
    
    reduced_universe = stock_universe
    
    if capThreshold != None:# and line['MarketCap'].value <capThreshold:
        reduced_universe = reduced_universe[reduced_universe['MarketCap']>=capThreshold]
        
    if sector != None:
        reduced_universe = reduced_universe[map(lambda x: x in sector, reduced_universe['Sector'].values)]
        
    if market != None:
        reduced_universe = reduced_universe[map(lambda x: x in market, reduced_universe['Market'].values)]
    
    if len(reduced_universe)<n:
        print '*******Warning: insufficient candidates, reduce number of samples'
        n = len(reduced_universe)
    
    if descendingByCap:
        # getting rid of redundant quotes, eg. goog and googl
        reduced_universe = reduced_universe.sort_values(by = 'MarketCap', ascending=False)[:n]

    else:
        reduced_universe = reduced_universe.sample(n)
    
    print 'Top 5 rows of selected portfolio:'
    print reduced_universe[['Symbol', 'Name', 'MarketCap', 'Sector', 'industry', 'Market']].head()
    
    return reduced_universe.Symbol.values

# %%
def getStocks(symbols, trim_start="2005-01-01", trim_end="2015-12-31"):
    """
    Paramters
    ---------
    symbols: list of string symbols. eg. ['AAPL', 'KCG']
    
    Returns
    -------
    a dictionary of pandas data frames containing all the close prices.
    """
    print symbols
    dfs = {}
    for symbol in symbols:
        flag = False
        #Get data from either Yahoo or Google 
        for source in ['YAHOO/', 'WIKI/', 'GOOG/NYSE_', 'GOOG/NASDAQ_', 'GOOG/AMEX_']:
            try:
                data = Quandl.get(source+symbol,authtoken='c2365v55yoZrWKxbVxwK',
                                  trim_start = trim_start, trim_end = trim_end)
                flag = True
                break
            except:
                pass
        
        if not flag:
            print 'Retrieving ' + symbol + ' unsuccessful. - No symbol. Suggesting:******'
            print Quandl.search(symbol)
            break
            
        else:
            try:
                data = data[['Adjusted Close']]
                data.columns = ['Close']
            except:
                try:
                    data = data[['Close']]
                except:
                    print 'Retrieving ' + symbol + ' unsuccessful. - No close data.'
                    data = None

        dfs[symbol] = data
        
    return dfs

# %% [markdown]
# ---

# %% [markdown]
# ###Following example

# %%
stock_universe = getStockUniverse()

# %%
stock_universe
# Out:
#      Symbol                                          Name LastSale  MarketCap  \
# 0      AAPL                                    Apple Inc.    96.91     537330
# 1      GOOG                                 Alphabet Inc.   705.07     485310
# 2      MSFT                         Microsoft Corporation     51.3     405750
# 3       XOM                       Exxon Mobil Corporation    81.75     340320
# 4        FB                                Facebook, Inc.   107.92     307170
# 5        GE                      General Electric Company    29.39     297110
# 6       JNJ                             Johnson & Johnson   105.78     292690
# 7      AMZN                              Amazon.com, Inc.   555.23     261430
# 8       WFC                         Wells Fargo & Company    48.07     245530
# 9         T                                     AT&T Inc.    37.13     228390
# 10      CHL                 China Mobile (Hong Kong) Ltd.    54.31     222400
# 11       PG                Procter & Gamble Company (The)     81.1     219340
# 12      WMT                         Wal-Mart Stores, Inc.    66.51     212960
# 13      JPM                         J P Morgan Chase & Co    57.54     211190
# 14       VZ                   Verizon Communications Inc.    51.02     207850
# 15       KO                       Coca-Cola Company (The)    43.14     187620
# 16      PFE                                  Pfizer, Inc.    30.23     186610
# 17      BUD                       Anheuser-Busch Inbev SA   112.27     180560
# 18      NVS                                   Novartis AG    72.03     170990
# 19     BABA                 Alibaba Group Holding Limited    66.91     166970
# 20       TM                     Toyota Motor Corp Ltd Ord   105.14     161610
# 21       HD                        Home Depot, Inc. (The)   126.26     160080
# 22        V                                     Visa Inc.    72.73     158850
# 23      CVX                           Chevron Corporation    84.35     158750
# 24      DIS                     Walt Disney Company (The)    95.31     155500
# 25     ORCL                            Oracle Corporation    36.96     155280
# 26      PEP                                 Pepsico, Inc.    98.36     142170
# 27       PM               Philip Morris International Inc    91.45     141690
# 28      MRK                         Merck & Company, Inc.    50.64     141470
# 29     INTC                             Intel Corporation     29.8     140780
# ...     ...                                           ...      ...        ...
# 5772    JGH                Nuveen Global High Income Fund     12.5         -1
# 5773   SPTN                           SpartanNash Company      n/a         -1
# 5774   ITEQ    BlueStar TA-BIGITech Israel Technology ETF  22.1611         -1
# 5775   HLM^                   Hillman Group Capital Trust  30.8501         -1
# 5776   GNRX              Market Vectors Generic Drugs ETF  23.8789         -1
# 5777   SPWH      Sportsman&#39;s Warehouse Holdings, Inc.      n/a         -1
# 5778   JMLP  Nuveen All Cap Energy MLP Opportunities Fund   5.3489         -1
# 5779   BOXL                          Boxlight Corporation      n/a         -1
# 5780    IBO  IBO (Listing Market - NYSE Amex Network B F)   153.82         -1
# 5781   SPSC                            SPS Commerce, Inc.      n/a         -1
# 5782    NSS                        NuStar Logistics, L.P.    20.49         -1
# 5783   BGCA                            BGC Partners, Inc.    25.81         -1
# 5784  NMK^B                 Niagara Mohawk Holdings, Inc.    91.25         -1
# 5785  BRK.A                       Berkshire Hathaway Inc.      n/a         -1
# 5786    NHF                NexPoint Credit Stategies Fund    17.55         -1
# 5787   NW^C                          Natl Westminster Pfd    25.54         -1
# 5788    GYC             Corporate Asset Backed Corp CABCO   21.556         -1
# 5789    SRF              Cushing Energy Income Fund (The)     6.55        NaN
# 5790    NRP                  Natural Resource Partners LP     7.81        NaN
# 5791   VXUP            AccuShares Spot CBOE VIX Up Shares    10.79        NaN
# 5792   AMDA                           Amedica Corporation     2.48        NaN
# 5793   FREE                                 FreeSeas Inc.   0.0354        NaN
# 5794   GBSN                  Great Basin Scientific, Inc.    0.188        NaN
# 5795   OMEX              Odyssey Marine Exploration, Inc.     2.55        NaN
# 5796   OPHC                    OptimumBank Holdings, Inc.     4.32        NaN
# 5797   QKLS                              QKL Stores, Inc.      0.5        NaN
# 5798     UK                    Recon Capital FTSE 100 ETF    18.73        NaN
# 5799   SGOC                              SGOCO Group, Ltd      3.4        NaN
# 5800    TOR                Sutor Technology Group Limited   0.4201        NaN
# 5801    NBY                 NovaBay Pharmaceuticals, Inc.     2.15        NaN
#
#      IPOyear                 Sector  \
# 0       1980             Technology
# 1       2004             Technology
# 2       1986             Technology
# 3        n/a                 Energy
# 4       2012             Technology
# 5        n/a                 Energy
# 6        n/a            Health Care
# 7       1997      Consumer Services
# 8        n/a                Finance
# 9        n/a       Public Utilities
# 10       n/a       Public Utilities
# 11       n/a       Basic Industries
# 12       n/a      Consumer Services
# 13       n/a                Finance
# 14       n/a       Public Utilities
# 15       n/a  Consumer Non-Durables
# 16       n/a            Health Care
# 17       n/a  Consumer Non-Durables
# 18       n/a            Health Care
# 19      2014          Miscellaneous
# 20       n/a          Capital Goods
# 21       n/a      Consumer Services
# 22       n/a          Miscellaneous
# 23       n/a                 Energy
# 24       n/a      Consumer Services
# 25      1986             Technology
# 26       n/a  Consumer Non-Durables
# 27       n/a  Consumer Non-Durables
# 28       n/a            Health Care
# 29       n/a             Technology
# ...      ...                    ...
# 5772    2014                    n/a
# 5773     n/a  Consumer Non-Durables
# 5774     n/a                    n/a
# 5775     n/a                    n/a
# 5776     n/a                    n/a
# 5777    2014      Consumer Services
# 5778    2014                    n/a
# 5779     n/a                    n/a
# 5780     n/a                    n/a
# 5781    2010             Technology
# 5782     n/a                 Energy
# 5783    2012                Finance
# 5784     n/a       Public Utilities
# 5785     n/a                    n/a
# 5786     n/a                    n/a
# 5787     n/a                Finance
# 5788     n/a                Finance
# 5789    2012                    n/a
# 5790    2002                 Energy
# 5791     n/a                    n/a
# 5792    2014            Health Care
# 5793     n/a         Transportation
# 5794    2014            Health Care
# 5795     n/a      Consumer Services
# 5796     n/a                Finance
# 5797     n/a      Consumer Services
# 5798     n/a                    n/a
# 5799    2010             Technology
# 5800     n/a          Capital Goods
# 5801    2007                    n/a
#
#                                                industry  \
# 0                                Computer Manufacturing
# 1       Computer Software: Programming, Data Processing
# 2               Computer Software: Prepackaged Software
# 3                              Integrated oil Companies
# 4       Computer Software: Programming, Data Processing
# 5                       Consumer Electronics/Appliances
# 6                                 Major Pharmaceuticals
# 7                        Catalog/Specialty Distribution
# 8                                           Major Banks
# 9                          Telecommunications Equipment
# 10                         Telecommunications Equipment
# 11                              Package Goods/Cosmetics
# 12                   Department/Specialty Retail Stores
# 13                                          Major Banks
# 14                         Telecommunications Equipment
# 15                  Beverages (Production/Distribution)
# 16                                Major Pharmaceuticals
# 17                  Beverages (Production/Distribution)
# 18                                Major Pharmaceuticals
# 19                                    Business Services
# 20                                   Auto Manufacturing
# 21                           RETAIL: Building Materials
# 22                                    Business Services
# 23                             Integrated oil Companies
# 24                                  Television Services
# 25              Computer Software: Prepackaged Software
# 26                  Beverages (Production/Distribution)
# 27                                Farming/Seeds/Milling
# 28                                Major Pharmaceuticals
# 29                                       Semiconductors
# ...                                                 ...
# 5772                                                n/a
# 5773                                  Food Distributors
# 5774                                                n/a
# 5775                                                n/a
# 5776                                                n/a
# 5777                             Other Specialty Stores
# 5778                                                n/a
# 5779                                                n/a
# 5780                                                n/a
# 5781            Computer Software: Prepackaged Software
# 5782                           Natural Gas Distribution
# 5783                 Investment Bankers/Brokers/Service
# 5784                                   Power Generation
# 5785                                                n/a
# 5786                                                n/a
# 5787                                   Commercial Banks
# 5788                         Finance: Consumer Services
# 5789                                                n/a
# 5790                                        Coal Mining
# 5791                                                n/a
# 5792                         Medical/Dental Instruments
# 5793                              Marine Transportation
# 5794                         Medical/Dental Instruments
# 5795                              Marine Transportation
# 5796                                        Major Banks
# 5797                                        Food Chains
# 5798                                                n/a
# 5799  Radio And Television Broadcasting And Communic...
# 5800                                     Steel/Iron Ore
# 5801                                                n/a
#
#                            Summary Quote  Market
# 0      http://www.nasdaq.com/symbol/aapl  NASDAQ
# 1      http://www.nasdaq.com/symbol/goog  NASDAQ
# 2      http://www.nasdaq.com/symbol/msft  NASDAQ
# 3       http://www.nasdaq.com/symbol/xom    NYSE
# 4        http://www.nasdaq.com/symbol/fb  NASDAQ
# 5        http://www.nasdaq.com/symbol/ge    NYSE
# 6       http://www.nasdaq.com/symbol/jnj    NYSE
# 7      http://www.nasdaq.com/symbol/amzn  NASDAQ
# 8       http://www.nasdaq.com/symbol/wfc    NYSE
# 9         http://www.nasdaq.com/symbol/t    NYSE
# 10      http://www.nasdaq.com/symbol/chl    NYSE
# 11       http://www.nasdaq.com/symbol/pg    NYSE
# 12      http://www.nasdaq.com/symbol/wmt    NYSE
# 13      http://www.nasdaq.com/symbol/jpm    NYSE
# 14       http://www.nasdaq.com/symbol/vz    NYSE
# 15       http://www.nasdaq.com/symbol/ko    NYSE
# 16      http://www.nasdaq.com/symbol/pfe    NYSE
# 17      http://www.nasdaq.com/symbol/bud    NYSE
# 18      http://www.nasdaq.com/symbol/nvs    NYSE
# 19     http://www.nasdaq.com/symbol/baba    NYSE
# 20       http://www.nasdaq.com/symbol/tm    NYSE
# 21       http://www.nasdaq.com/symbol/hd    NYSE
# 22        http://www.nasdaq.com/symbol/v    NYSE
# 23      http://www.nasdaq.com/symbol/cvx    NYSE
# 24      http://www.nasdaq.com/symbol/dis    NYSE
# 25     http://www.nasdaq.com/symbol/orcl    NYSE
# 26      http://www.nasdaq.com/symbol/pep    NYSE
# 27       http://www.nasdaq.com/symbol/pm    NYSE
# 28      http://www.nasdaq.com/symbol/mrk    NYSE
# 29     http://www.nasdaq.com/symbol/intc  NASDAQ
# ...                                  ...     ...
# 5772    http://www.nasdaq.com/symbol/jgh    NYSE
# 5773   http://www.nasdaq.com/symbol/sptn  NASDAQ
# 5774   http://www.nasdaq.com/symbol/iteq  NASDAQ
# 5775   http://www.nasdaq.com/symbol/hlm^    AMEX
# 5776   http://www.nasdaq.com/symbol/gnrx  NASDAQ
# 5777   http://www.nasdaq.com/symbol/spwh  NASDAQ
# 5778   http://www.nasdaq.com/symbol/jmlp    NYSE
# 5779   http://www.nasdaq.com/symbol/boxl  NASDAQ
# 5780    http://www.nasdaq.com/symbol/ibo    AMEX
# 5781   http://www.nasdaq.com/symbol/spsc  NASDAQ
# 5782    http://www.nasdaq.com/symbol/nss    NYSE
# 5783   http://www.nasdaq.com/symbol/bgca    NYSE
# 5784  http://www.nasdaq.com/symbol/nmk^b    NYSE
# 5785  http://www.nasdaq.com/symbol/brk.a    NYSE
# 5786    http://www.nasdaq.com/symbol/nhf    NYSE
# 5787   http://www.nasdaq.com/symbol/nw^c    NYSE
# 5788    http://www.nasdaq.com/symbol/gyc    NYSE
# 5789    http://www.nasdaq.com/symbol/srf    NYSE
# 5790    http://www.nasdaq.com/symbol/nrp    NYSE
# 5791   http://www.nasdaq.com/symbol/vxup  NASDAQ
# 5792   http://www.nasdaq.com/symbol/amda  NASDAQ
# 5793   http://www.nasdaq.com/symbol/free  NASDAQ
# 5794   http://www.nasdaq.com/symbol/gbsn  NASDAQ
# 5795   http://www.nasdaq.com/symbol/omex  NASDAQ
# 5796   http://www.nasdaq.com/symbol/ophc  NASDAQ
# 5797   http://www.nasdaq.com/symbol/qkls  NASDAQ
# 5798     http://www.nasdaq.com/symbol/uk  NASDAQ
# 5799   http://www.nasdaq.com/symbol/sgoc  NASDAQ
# 5800    http://www.nasdaq.com/symbol/tor  NASDAQ
# 5801    http://www.nasdaq.com/symbol/nby    AMEX
#
# [5802 rows x 9 columns]

# %%
techgiants = getSamplePortfolio(stock_universe, sector = ['Technology'], descendingByCap = True)
# Out:
# Top 5 rows of selected portfolio:
#    Symbol                   Name  MarketCap      Sector  \
# 0    AAPL             Apple Inc.     537330  Technology
# 1    GOOG          Alphabet Inc.     485310  Technology
# 2    MSFT  Microsoft Corporation     405750  Technology
# 4      FB         Facebook, Inc.     307170  Technology
# 25   ORCL     Oracle Corporation     155280  Technology
#
#                                            industry  Market
# 0                            Computer Manufacturing  NASDAQ
# 1   Computer Software: Programming, Data Processing  NASDAQ
# 2           Computer Software: Prepackaged Software  NASDAQ
# 4   Computer Software: Programming, Data Processing  NASDAQ
# 25          Computer Software: Prepackaged Software    NYSE

# %%
techgiants
# Out:
# array(['AAPL', 'GOOG', 'MSFT', 'FB', 'ORCL', 'INTC', 'CSCO', 'IBM', 'TSM',
#        'DCM'], dtype=object)

# %%
techgiants_p = getStocks(techgiants)
# Out:
# ['AAPL' 'GOOG' 'MSFT' 'FB' 'ORCL' 'INTC' 'CSCO' 'IBM' 'TSM' 'DCM']

# %%
techgiants_p['ORCL']
# Out:
#                 Close
# Date
# 2005-01-03  12.453647
# 2005-01-04  12.128609
# 2005-01-05  12.165756
# 2005-01-06  12.277198
# 2005-01-07  12.379353
# 2005-01-10  12.249337
# 2005-01-11  12.258624
# 2005-01-12  12.518655
# 2005-01-13  12.518655
# 2005-01-14  12.657958
# 2005-01-18  12.797260
# 2005-01-19  12.509369
# 2005-01-20  12.332918
# 2005-01-21  12.360780
# 2005-01-24  12.295771
# 2005-01-25  12.620811
# 2005-01-26  12.648671
# 2005-01-27  12.973711
# 2005-01-28  12.704392
# 2005-01-31  12.787974
# 2005-02-01  12.676531
# 2005-02-02  12.592951
# 2005-02-03  12.388640
# 2005-02-04  12.685818
# 2005-02-07  12.583663
# 2005-02-08  12.509369
# 2005-02-09  12.230764
# 2005-02-10  12.202903
# 2005-02-11  12.397927
# 2005-02-14  12.360780
# ...               ...
# 2015-11-18  38.541090
# 2015-11-19  38.859776
# 2015-11-20  39.178461
# 2015-11-23  38.979282
# 2015-11-24  39.297968
# 2015-11-25  39.098788
# 2015-11-27  39.019118
# 2015-11-30  38.809982
# 2015-12-01  39.068912
# 2015-12-02  38.541090
# 2015-12-03  37.654745
# 2015-12-04  38.999200
# 2015-12-07  38.660596
# 2015-12-08  38.570966
# 2015-12-09  38.421584
# 2015-12-10  38.033182
# 2015-12-11  37.057207
# 2015-12-14  37.495402
# 2015-12-15  38.053100
# 2015-12-16  38.750227
# 2015-12-17  36.778357
# 2015-12-18  36.200737
# 2015-12-21  36.270450
# 2015-12-22  36.439753
# 2015-12-23  36.778357
# 2015-12-24  36.858027
# 2015-12-28  36.638933
# 2015-12-29  36.887906
# 2015-12-30  36.768396
# 2015-12-31  36.379998
#
# [2769 rows x 1 columns]
