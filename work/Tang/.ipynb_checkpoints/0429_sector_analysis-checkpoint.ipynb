# %%
from StockDescription import *
from Hedge import Hedge

import sys
sys.path.append('../../source/')

import numpy as np
import pandas as pd
stockuniverse = getStockUniverse()

# %%
techs = getSamplePortfolio(stockuniverse,sector=['Technology'])
consumer_durable = getSamplePortfolio(stockuniverse,sector=['Consumer Durables'])
energy = getSamplePortfolio(stockuniverse, sector=['Energy'])
health_care = getSamplePortfolio(stockuniverse, sector=['Health Care'])
# Out:
# *******Warning: insufficient candidates, reduce number of samples
# Top 5 rows of selected portfolio:
#      Symbol                                         Name  MarketCap  \
# 1062    PTC                                     PTC Inc.       3580
# 1399    FCS  Fairchild Semiconductor International, Inc.       2270
# 1039    SNX                           Synnex Corporation       3730
# 845    MIDD                     The Middleby Corporation       5190
# 1364   MLNX                  Mellanox Technologies, Ltd.       2360
#
#           Sector                                          industry  Market
# 1062  Technology           Computer Software: Prepackaged Software  NASDAQ
# 1399  Technology                                    Semiconductors  NASDAQ
# 1039  Technology  Retail: Computer Software & Peripheral Equipment    NYSE
# 845   Technology                   Industrial Machinery/Components  NASDAQ
# 1364  Technology                                    Semiconductors  NASDAQ
# *******Warning: insufficient candidates, reduce number of samples
# Top 5 rows of selected portfolio:
#      Symbol                                               Name  MarketCap  \
# 911     PKG                   Packaging Corporation of America       4690
# 1079   POOL                                   Pool Corporation       3490
# 631      GT                 The Goodyear Tire & Rubber Company       8080
# 320      NJ  Nidec Corporation (Nihon Densan Kabushiki Kaisha)      19930
# 1303   LFUS                                   Littelfuse, Inc.       2540
#
#                  Sector                industry  Market
# 911   Consumer Durables    Containers/Packaging    NYSE
# 1079  Consumer Durables  Industrial Specialties  NASDAQ
# 631   Consumer Durables  Automotive Aftermarket  NASDAQ
# 320   Consumer Durables      Metal Fabrications    NYSE
# 1303  Consumer Durables     Electrical Products  NASDAQ
# *******Warning: insufficient candidates, reduce number of samples
# Top 5 rows of selected portfolio:
#      Symbol                             Name  MarketCap  Sector  \
# 1269    OII  Oceaneering International, Inc.       2670  Energy
# 225     HAL              Halliburton Company      28160  Energy
# 1355    NBR           Nabors Industries Ltd.       2410  Energy
# 612     COG      Cabot Oil & Gas Corporation       8460  Energy
# 865     WFT    Weatherford International plc       5010  Energy
#
#                          industry Market
# 1269  Oilfield Services/Equipment   NYSE
# 225   Oilfield Services/Equipment   NYSE
# 1355         Oil & Gas Production   NYSE
# 612          Oil & Gas Production   NYSE
# 865            Metal Fabrications   NYSE
# *******Warning: insufficient candidates, reduce number of samples
# Top 5 rows of selected portfolio:
#      Symbol                             Name  MarketCap       Sector  \
# 938    PDCO        Patterson Companies, Inc.       4420  Health Care
# 645     MNK                 Mallinckrodt plc       7750  Health Care
# 1091   ABMD                    ABIOMED, Inc.       3420  Health Care
# 43      UNH  UnitedHealth Group Incorporated     115350  Health Care
# 1308    THC     Tenet Healthcare Corporation       2530  Health Care
#
#                          industry  Market
# 938          Medical Specialities  NASDAQ
# 645         Major Pharmaceuticals    NYSE
# 1091   Medical/Dental Instruments  NASDAQ
# 43           Medical Specialities    NYSE
# 1308  Hospital/Nursing Management    NYSE

# %%
hedge_tech = Hedge(begindate='2013-01-01', enddate='2014-12-31',fromlist=techs)
hedge_tech.market = hedge_tech.stockuniverse
tech_returns = hedge_tech.dollar_market_sum_ret
tech_port = hedge_tech.dollar_market_sum

# %%
hedge_consumer_durable = Hedge(begindate='2013-01-01', enddate='2014-12-31',fromlist=consumer_durable)
hedge_consumer_durable.market = hedge_consumer_durable.stockuniverse
consumer_durable_returns = hedge_consumer_durable.dollar_market_sum_ret
consumer_durable_port = hedge_consumer_durable.dollar_market_sum

# %%
hedge_health = Hedge(begindate='2013-01-01', enddate='2014-12-31',fromlist=health_care)
hedge_health.market = hedge_health.stockuniverse
health_returns = hedge_health.dollar_market_sum_ret
health_port = hedge_health.dollar_market_sum

# %%
hedge_energy = Hedge(begindate='2013-01-01', enddate='2014-12-31',fromlist=energy)
hedge_energy.market = hedge_energy.stockuniverse
energy_returns = hedge_energy.dollar_market_sum_ret
energy_port = hedge_energy.dollar_market_sum

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(16, 12))
tech_port.plot(label='Technology')
consumer_durable_port.plot(label='Consumer Durables')
health_port.plot(label='Health Care')
energy_port.plot(label='Energy')
(hedge_tech.spy/hedge_tech.spy.values[0]*1000).plot(label='SPY')
plt.legend(loc = 2)
