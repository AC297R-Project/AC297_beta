# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('../../source')
import matplotlib.pylab as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('white')
sns.set_context('talk')

from BetaUtils import beta_hedging_ret, get_beta
from energy_functions import correlation, neg_returns, volatility
from Hedge import Hedge

import datetime

# %%
from plotting_functions import *

# %%
with open('../../source/portfolios_2.txt', 'r') as f:
    a = f.readlines()

# %%
with open('portfolio_static.txt','w') as f:
    for ii in range(199):
        f.write(a[0].replace("'",''))

# %%
markets=[]
for ii in range(1,200):
    with open('../../source/results/bestmarket_'+str(ii)+'.txt','r') as g:
        markets.append(g.read())

with open('markets_static.txt','w') as f:
    for ii in range(0,199):
        f.write(str(ii)+','+markets[ii][:-1].replace('[','').replace(']','').replace("'","")[:-1]+'\n')

# %%
batch_results_plotter('portfolio_static.txt','markets_static.txt',None,'2006-10-01','2007-12-31')
# Out:
# Bar plot 0
# Bar plot 1
# Bar plot 2
# Bar plot 3
# Bar plot 4
# Bar plot 5
# Bar plot 6
# Bar plot 7
# Bar plot 8
# Bar plot 9
# Bar plot 10
# Bar plot 11
# Bar plot 12
# Bar plot 13
# Bar plot 14
# Bar plot 15
# Bar plot 16
# Bar plot 17
# Bar plot 18
# Bar plot 19
# Bar plot 20
# Bar plot 21
# Bar plot 22
# Bar plot 23
# Bar plot 24
# Bar plot 25
# Bar plot 26
# Bar plot 27
# Bar plot 28
# Bar plot 29
# Bar plot 30
# Bar plot 31
# Bar plot 32
# Bar plot 33
# Bar plot 34
# Bar plot 35
# Bar plot 36
# Bar plot 37
# Bar plot 38
# Bar plot 39
# Bar plot 40
# Bar plot 41
# Bar plot 42
# Bar plot 43
# Bar plot 44
# Bar plot 45
# Bar plot 46
# Bar plot 47
# Bar plot 48
# Bar plot 49
# Bar plot 50
# Bar plot 51
# Bar plot 52
# Bar plot 53
# Bar plot 54
# Bar plot 55
# Bar plot 56
# Bar plot 57
# Bar plot 58
# Bar plot 59
# Bar plot 60
# Bar plot 61
# Bar plot 62
# Bar plot 63
# Bar plot 64
# Bar plot 65
# Bar plot 66
# Bar plot 67
# Bar plot 68
# Bar plot 69
# Bar plot 70
# Bar plot 71
# ...

# %%
with open('../../source/portfolios_2.txt', 'r') as f:
    a = f.readlines()
with open('portfolio_static2.txt','w') as f:
    for ii in range(200):
        f.write(a[0].replace("'",''))
markets=[]
for ii in range(200,400):
    with open('../../source/results/bestmarket_'+str(ii)+'.txt','r') as g:
        markets.append(g.read())

with open('markets_static2.txt','w') as f:
    for ii in range(0,200):
        f.write(str(ii)+','+markets[ii][:-1].replace('[','').replace(']','').replace("'","")[:-1]+'\n')

# %%
batch_results_plotter('portfolio_static2.txt','markets_static2.txt',None,'2007-10-01','2008-12-31')
# Out:
# Bar plot 0
# Bar plot 1
# Bar plot 2
# Bar plot 3
# Bar plot 4
# Bar plot 5
# Bar plot 6
# Bar plot 7
# Bar plot 8
# Bar plot 9
# Bar plot 10
# Bar plot 11
# Bar plot 12
# Bar plot 13
# Bar plot 14
# Bar plot 15
# Bar plot 16
# Bar plot 17
# Bar plot 18
# Bar plot 19
# Bar plot 20
# Bar plot 21
# Bar plot 22
# Bar plot 23
# Bar plot 24
# Bar plot 25
# Bar plot 26
# Bar plot 27
# Bar plot 28
# Bar plot 29
# Bar plot 30
# Bar plot 31
# Bar plot 32
# Bar plot 33
# Bar plot 34
# Bar plot 35
# Bar plot 36
# Bar plot 37
# Bar plot 38
# Bar plot 39
# Bar plot 40
# Bar plot 41
# Bar plot 42
# Bar plot 43
# Bar plot 44
# Bar plot 45
# Bar plot 46
# Bar plot 47
# Bar plot 48
# Bar plot 49
# Bar plot 50
# Bar plot 51
# Bar plot 52
# Bar plot 53
# Bar plot 54
# Bar plot 55
# Bar plot 56
# Bar plot 57
# Bar plot 58
# Bar plot 59
# Bar plot 60
# Bar plot 61
# Bar plot 62
# Bar plot 63
# Bar plot 64
# Bar plot 65
# Bar plot 66
# Bar plot 67
# Bar plot 68
# Bar plot 69
# Bar plot 70
# Bar plot 71
# ...
